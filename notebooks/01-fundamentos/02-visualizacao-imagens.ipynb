# %% [markdown]
# <a href="https://colab.research.google.com/github/mbilby/trilha-visao-computacional/blob/main/notebooks/01-fundamentos/02-visualizacao-imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # M1A3 - Visualização de Imagens

# %% [markdown]
# Nessa aula vamos aprender como visualizar imagens utilizando Matplotlib
#
# Esse notebook está estruturado da seguinte forma:
#
# *   Instalação
# *   Ler imagem do disco
# *   Visualização de imagens
# *   Próximos passos
# *   Atividade complementar

# %% [markdown]
# Instalação e importação de Biblioteca

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ler imagens do disco

# %% [markdown]
# Nossa primeira aula é ler imagens do disco.
#
# Para isso utilizaremos a função plt.imread

# %%
# TODO Atualize o path imagem.
image = plt.imread("/content/sample_data/radiology.jpg")
#

# %% [markdown]
# É possivel observar qual o tipo de dados da imagem e visualizar valores de cada pixel da imagem.

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
image[0, 0]
# Out:
# array([0, 0, 0], dtype=uint8)

# %% [markdown]
# # Visualizar imagens

# %%
plt.imshow(image)

# %% [markdown]
# # Próximos Passos

# %% [markdown]
# Referências
#
# *   https://matplotlib.org/stable
# *   https://matplotlib.org/stable/tutorials/images.html

# %% [markdown]
# # Atividades Complementares (Opcional)
#
# *   Leia outra imagem do arquivo rio.jpeg e rode todos os comandos
# *   Altere o espaço de cores e visualize a imagem
# *   Podemos visualizar imagens que não foram lidas do disco utilizado plt.imread? Talvez criando vetores em numpy?
